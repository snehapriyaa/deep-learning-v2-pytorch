# %% [markdown]
# # Convolutional Neural Networks
# ---
# In this notebook, we train a **CNN** to classify images from the CIFAR-10 database.
#
# The images in this database are small color images that fall into one of ten classes; some example images are pictured below.
#
# <img src='notebook_ims/cifar_data.png' width=70% height=70% />

# %% [markdown]
# ### Test for [CUDA](http://pytorch.org/docs/stable/cuda.html)
#
# Since these are larger (32x32x3) images, it may prove useful to speed up your training time by using a GPU. CUDA is a parallel computing platform and CUDA Tensors are the same as typical Tensors, only they utilize GPU's for computation.

# %%
import torch
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
    
print("Training on %s ..." % device.upper())
# Out:
# Training on CUDA ...

# %% [markdown]
# ---
# ## Load the [Data](http://pytorch.org/docs/stable/torchvision/datasets.html)
#
# Downloading may take a minute. We load in the training and test data, split the training data into a training and validation set, then create DataLoaders for each of these sets of data.

# %%
from torchvision import datasets
import torchvision.transforms as transforms

from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler

from sklearn.model_selection import train_test_split

# number of subprocesses to use for data loading
num_workers = 8
# how many samples per batch to load
batch_size = 128
# percentage of training set to use as validation
valid_size = 0.2

normalize = transforms.Normalize((0.5, 0.5, 0.5),
                                 (0.5, 0.5, 0.5))

# convert data to a normalized torch.FloatTensor
train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(45),
                                      transforms.ToTensor(),
                                      normalize])

test_transform = transforms.Compose([transforms.ToTensor(),
                                     normalize])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,  download=True, transform=train_transform)
test_data  = datasets.CIFAR10('data', train=False, download=True, transform=test_transform)

test_idx, valid_idx = train_test_split(np.arange(len(test_data)), test_size=valid_size)

test_sampler  = SubsetRandomSampler(test_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data,
                                           batch_size=batch_size,
                                           num_workers=num_workers)

valid_loader = torch.utils.data.DataLoader(test_data,
                                           batch_size=batch_size,
                                           sampler=valid_sampler,
                                           num_workers=num_workers)

test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=batch_size,
                                          sampler=test_sampler,
                                          num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
    img = img / 2 + 0.5  # unnormalize
    plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# %%
# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title(classes[labels[idx]])

# %% [markdown]
# ### View an Image in More Detail
#
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
rgb_img = np.squeeze(images[3])

channels = [
    'red channel',
    'green channel',
    'blue channel',
]

fig = plt.figure(figsize = (36, 36))

for idx in range(len(channels)):
    ax = fig.add_subplot(1, len(channels), idx + 1)
    img = rgb_img[idx]
    ax.imshow(img, cmap='gray')
    ax.set_title(channels[idx])
    width, height = img.shape
    thresh = img.max()/2.5
    for x in range(width):
        for y in range(height):
            val = round(img[x][y],2) if img[x][y] != 0 else 0
            ax.annotate(str(val), xy=(y,x),
                    horizontalalignment='center',
                    verticalalignment='center', size=8,
                    color='white' if img[x][y] < thresh else 'black')

# %% [markdown]
# ---
# ## Define the Network [Architecture](http://pytorch.org/docs/stable/nn.html)
#
# This time, you'll define a CNN architecture. Instead of an MLP, which used linear, fully-connected layers, you'll use the following:
# * [Convolutional layers](https://pytorch.org/docs/stable/nn.html#conv2d), which can be thought of as stack of filtered images.
# * [Maxpooling layers](https://pytorch.org/docs/stable/nn.html#maxpool2d), which reduce the x-y size of an input, keeping only the most _active_ pixels from the previous layer.
# * The usual Linear + Dropout layers to avoid overfitting and produce a 10-dim output.
#
# A network with 2 convolutional layers is shown in the image below and in the code, and you've been given starter code with one convolutional and one maxpooling layer.
#
# <img src='notebook_ims/2_layer_conv.png' height=50% width=50% />
#
# #### TODO: Define a model with multiple convolutional layers, and define the feedforward metwork behavior.
#
# The more convolutional layers you include, the more complex patterns in color and shape a model can detect. It's suggested that your final model include 2 or 3 convolutional layers as well as linear layers + dropout in between to avoid overfitting.
#
# It's good practice to look at existing research and implementations of related models as a starting point for defining your own models. You may find it useful to look at [this PyTorch classification example](https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py) or [this, more complex Keras example](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py) to help decide on a final structure.
#
# #### Output volume for a convolutional layer
#
# To compute the output size of a given convolutional layer we can perform the following calculation (taken from [Stanford's cs231n course](http://cs231n.github.io/convolutional-networks/#layers)):
# > We can compute the spatial size of the output volume as a function of the input volume size (W), the kernel/filter size (F), the stride with which they are applied (S), and the amount of zero padding used (P) on the border. The correct formula for calculating how many neurons define the output_W is given by `(W−F+2P)/S+1`.
#
# For example for a 7x7 input and a 3x3 filter with stride 1 and pad 0 we would get a 5x5 output. With stride 2 we would get a 3x3 output.

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d( 3, 32, 3, padding=1) # => 32x32
        self.conv2 = nn.Conv2d(32, 32, 3)            # => 30x30
        
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1) # => 15x15
        self.conv4 = nn.Conv2d(64, 64, 3)            # => 13x13

        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        
        self.fc1 = nn.Linear(64 * 6 * 6, 512)
        self.fc2 = nn.Linear(512, 10)
        
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = self.dropout(self.pool(x)) # => 15x15

        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.dropout(self.pool(x)) # => 6x6
        
        x = x.view(-1, 64 * 6 * 6)
        
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        
        return x, F.softmax(x, dim=1)

# create a complete CNN
model = Net().to(device)

display(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2304, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ### Specify [Loss Function](http://pytorch.org/docs/stable/nn.html#loss-functions) and [Optimizer](http://pytorch.org/docs/stable/optim.html)
#
# Decide on a loss and optimization function that is best suited for this classification task. The linked code examples from above, may be a good starting point; [this PyTorch classification example](https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py) or [this, more complex Keras example](https://github.com/keras-team/keras/blob/master/examples/cifar10_cnn.py). Pay close attention to the value for **learning rate** as this value determines how your model converges to a small error.
#
# #### TODO: Define the loss and optimizer and see how these choices change the loss over time.

# %%
import torch.optim as optim

# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.Adam(model.parameters())

# %% [markdown]
# ---
# ## Train the Network
#
# Remember to look at how the training and validation loss decreases over time; if the validation loss ever increases it indicates possible overfitting.

# %%
n_epochs = 50

valid_loss_min = np.Inf # track change in validation loss

train_losses, valid_losses = [], []

for epoch in range(n_epochs):
    # keep track of training and validation loss
    cum_train_loss = 0.
    cum_valid_loss = 0.
    
    ###################
    # train the model #
    ###################
    model.train()
    
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)
        
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        logits, _ = model.forward(data)
        # calculate the batch loss        
        loss = criterion(logits, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update training loss
        cum_train_loss += loss.item() * len(data)
        
    ######################    
    # validate the model #
    ######################
    model.eval()
    
    for data, target in valid_loader:
        with torch.no_grad():
            data, target = data.to(device), target.to(device)
            # forward pass: compute predicted outputs by passing inputs to the model
            logits, _ = model.forward(data)
            # calculate the batch loss
            loss = criterion(logits, target)
            # update average validation loss 
            cum_valid_loss += loss.item() * len(data)
    
    # calculate average losses
    train_loss = cum_train_loss / len(train_data)
    valid_loss = cum_valid_loss / len(valid_idx)
    
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
        
    # print training/validation statistics 
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch + 1, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model_cifar.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.696222 	Validation Loss: 1.366647
# Validation loss decreased (inf --> 1.366647). Saving model ...
# Epoch: 2 	Training Loss: 1.400201 	Validation Loss: 1.193721
# Validation loss decreased (1.366647 --> 1.193721). Saving model ...
# Epoch: 3 	Training Loss: 1.253528 	Validation Loss: 1.083445
# Validation loss decreased (1.193721 --> 1.083445). Saving model ...
# Epoch: 4 	Training Loss: 1.164148 	Validation Loss: 1.010305
# Validation loss decreased (1.083445 --> 1.010305). Saving model ...
# Epoch: 5 	Training Loss: 1.097483 	Validation Loss: 0.939557
# Validation loss decreased (1.010305 --> 0.939557). Saving model ...
# Epoch: 6 	Training Loss: 1.048587 	Validation Loss: 0.903062
# Validation loss decreased (0.939557 --> 0.903062). Saving model ...
# Epoch: 7 	Training Loss: 1.008053 	Validation Loss: 0.875106
# Validation loss decreased (0.903062 --> 0.875106). Saving model ...
# Epoch: 8 	Training Loss: 0.967966 	Validation Loss: 0.845434
# Validation loss decreased (0.875106 --> 0.845434). Saving model ...
# Epoch: 9 	Training Loss: 0.948426 	Validation Loss: 0.867472
# Epoch: 10 	Training Loss: 0.920168 	Validation Loss: 0.794913
# Validation loss decreased (0.845434 --> 0.794913). Saving model ...
# Epoch: 11 	Training Loss: 0.890693 	Validation Loss: 0.796590
# Epoch: 12 	Training Loss: 0.875259 	Validation Loss: 0.756863
# Validation loss decreased (0.794913 --> 0.756863). Saving model ...
# Epoch: 13 	Training Loss: 0.851783 	Validation Loss: 0.753889
# Validation loss decreased (0.756863 --> 0.753889). Saving model ...
# Epoch: 14 	Training Loss: 0.835123 	Validation Loss: 0.737324
# Validation loss decreased (0.753889 --> 0.737324). Saving model ...
# Epoch: 15 	Training Loss: 0.823444 	Validation Loss: 0.727248
# Validation loss decreased (0.737324 --> 0.727248). Saving model ...
# Epoch: 16 	Training Loss: 0.816137 	Validation Loss: 0.731561
# Epoch: 17 	Training Loss: 0.798954 	Validation Loss: 0.725929
# Validation loss decreased (0.727248 --> 0.725929). Saving model ...
# Epoch: 18 	Training Loss: 0.794280 	Validation Loss: 0.729021
# Epoch: 19 	Training Loss: 0.784952 	Validation Loss: 0.711785
# Validation loss decreased (0.725929 --> 0.711785). Saving model ...
# Epoch: 20 	Training Loss: 0.765327 	Validation Loss: 0.702736
# Validation loss decreased (0.711785 --> 0.702736). Saving model ...
# Epoch: 21 	Training Loss: 0.768421 	Validation Loss: 0.683269
# Validation loss decreased (0.702736 --> 0.683269). Saving model ...
# Epoch: 22 	Training Loss: 0.756433 	Validation Loss: 0.692601
# Epoch: 23 	Training Loss: 0.742627 	Validation Loss: 0.696897
# Epoch: 24 	Training Loss: 0.739776 	Validation Loss: 0.689009
# Epoch: 25 	Training Loss: 0.737189 	Validation Loss: 0.673373
# Validation loss decreased (0.683269 --> 0.673373). Saving model ...
# Epoch: 26 	Training Loss: 0.728097 	Validation Loss: 0.676802
# Epoch: 27 	Training Loss: 0.726419 	Validation Loss: 0.665123
# Validation loss decreased (0.673373 --> 0.665123). Saving model ...
# Epoch: 28 	Training Loss: 0.722967 	Validation Loss: 0.670411
# Epoch: 29 	Training Loss: 0.709824 	Validation Loss: 0.666209
# Epoch: 30 	Training Loss: 0.712599 	Validation Loss: 0.636532
# Validation loss decreased (0.665123 --> 0.636532). Saving model ...
# Epoch: 31 	Training Loss: 0.703005 	Validation Loss: 0.647535
# Epoch: 32 	Training Loss: 0.698060 	Validation Loss: 0.630072
# Validation loss decreased (0.636532 --> 0.630072). Saving model ...
# Epoch: 33 	Training Loss: 0.693232 	Validation Loss: 0.634893
# Epoch: 34 	Training Loss: 0.686515 	Validation Loss: 0.642639
# Epoch: 35 	Training Loss: 0.688234 	Validation Loss: 0.652334
# Epoch: 36 	Training Loss: 0.687524 	Validation Loss: 0.635788
# Epoch: 37 	Training Loss: 0.682963 	Validation Loss: 0.640927
# Epoch: 38 	Training Loss: 0.676737 	Validation Loss: 0.631813
# Epoch: 39 	Training Loss: 0.676519 	Validation Loss: 0.630272
# Epoch: 40 	Training Loss: 0.672126 	Validation Loss: 0.646957
# Epoch: 41 	Training Loss: 0.671959 	Validation Loss: 0.630296
# Epoch: 42 	Training Loss: 0.668719 	Validation Loss: 0.643840
# Epoch: 43 	Training Loss: 0.654539 	Validation Loss: 0.627379
# Validation loss decreased (0.630072 --> 0.627379). Saving model ...
# Epoch: 44 	Training Loss: 0.653753 	Validation Loss: 0.613270
# Validation loss decreased (0.627379 --> 0.613270). Saving model ...
# Epoch: 45 	Training Loss: 0.658168 	Validation Loss: 0.628232
# Epoch: 46 	Training Loss: 0.646169 	Validation Loss: 0.628761
# Epoch: 47 	Training Loss: 0.652352 	Validation Loss: 0.632795
# Epoch: 48 	Training Loss: 0.653474 	Validation Loss: 0.637048
# Epoch: 49 	Training Loss: 0.645397 	Validation Loss: 0.640361
# Epoch: 50 	Training Loss: 0.642263 	Validation Loss: 0.613869

# %%
plt.plot(train_losses, label="Train losses")
plt.plot(valid_losses, label="Valid losses")
plt.legend()
plt.grid();

# %% [markdown]
# ###  Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model_cifar.pt'))

# %% [markdown]
# ---
# ## Test the Trained Network
#
# Test your trained model on previously unseen data! A "good" result will be a CNN that gets around 70% (or more, try your best!) accuracy on these test images.

# %%
# track test loss
test_loss = 0.
class_total = list(0. for i in range(10))
class_correct = list(0. for i in range(10))

model.eval()

# iterate over test data
for data, target in test_loader:
    data, target = data.to(device), target.to(device)
    
    # forward pass: compute predicted outputs by passing inputs to the model
    logits, _ = model.forward(data)
    # calculate the batch loss
    loss = criterion(logits, target)
    # update test loss 
    test_loss += loss.item() * len(data)
    # convert output probabilities to predicted class
    _, pred = torch.max(logits, dim=1)
    # compare predictions to true label
    correct_tensor = pred.eq(target.data.view_as(pred))
    correct = np.squeeze(correct_tensor.numpy()) if not device == "cuda" else np.squeeze(correct_tensor.cpu().numpy())
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_idx)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            classes[i], 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2.2f%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.602964
#
# Test Accuracy of airplane: 79% (637/801)
# Test Accuracy of automobile: 90% (717/789)
# Test Accuracy of  bird: 69% (564/815)
# Test Accuracy of   cat: 65% (536/815)
# Test Accuracy of  deer: 75% (597/793)
# Test Accuracy of   dog: 74% (612/818)
# Test Accuracy of  frog: 85% (694/813)
# Test Accuracy of horse: 85% (675/794)
# Test Accuracy of  ship: 89% (696/781)
# Test Accuracy of truck: 85% (667/781)
#
# Test Accuracy (Overall): 79.94% (6395/8000)

# %% [markdown]
# ### Question: What are your model's weaknesses and how might they be improved?

# %% [markdown]
# **Answer**: (double-click to edit and add an answer)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
images = images.to(device)

# get sample outputs
logits, _ = model.forward(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(logits, dim=1)
preds = np.squeeze(preds_tensor.numpy()) if not device == "cuda" else np.squeeze(preds_tensor.cpu().numpy())

# plot the images in the batch, along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])
    ax.set_title("{} ({})".format(classes[preds[idx]], classes[labels[idx]]),
                 color=("green" if preds[idx]==labels[idx].item() else "red"))
